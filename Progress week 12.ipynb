# %% [markdown]
# ## Progress

# %% [markdown]
# This week, there is still not much progress. Eventually, I got one day that I really worked on the project. I managed to add one of the missing libraries needed for the connection of the epuck. Whilst trying to add the other library to the path my ubuntu crashed. When trying to start up ubuntu afterwards this error showed up everytime. It seems that I moved a folder that wasn't allowed to be moved and therefore the system crashes. I was not yet able to solve this problem. Monday, I will work at the setup to try and catch up with the lost progress.

# %% [markdown]
# ![WhatsApp%20Image%202022-02-21%20at%2000.26.46.jpeg](attachment:WhatsApp%20Image%202022-02-21%20at%2000.26.46.jpeg)
