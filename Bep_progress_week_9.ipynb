# %% [markdown]
# ## Bep Progress Week 9

# %% [markdown]
# #### Camera software

# %% [markdown]
# For the camera software there was a package downloaded from their site: https://www.alliedvision.com/en/support/software-downloads/. The manual on that same site was followed to install this software. However, there was a problem during the installation of the GigE Sample Viewer. For the installation of the Sample Viewer there are libaries needed that to this point I was unable to install. For the x64 Sample Viewer the library libtiff.so.4 was needed. As it can be seen on the photo below the libtiff package was downloaded but the libtiff4 couldn't be found:
# ![libtiff4_library.JPG](attachment:libtiff4_library.JPG)
# It is stated that the source is missing or only availble on another source. I tried many other sources but on all of them only libtiff5-dev was availble but not libtiff4
#
# For the Sample Viewer in the x86 folder the library libpng12.so.0 was needed. For this library it was the same story as the libtiff library. I installed the package from a lot of sources libpng libraries but still the libpng12.so.0 was missing.

# %% [markdown]
# #### Bluetooth connection

# %% [markdown]
# For the bluetooth connection the error that I got was that there was no profile with UUID. Erjen gave a good tip that it could be something with the bluetooth connection. When trying to run bluetoothctl en show it was stated that there was no default controller. After some installations for the bluetooth this error still occured. I hope this problem will be solved when the bluetooth drivers are activated. However, this is not the entirely the solution. I tried running the startAllEpucks on my own laptop, where the bluetooth is working fine, without installing the camera software to see if that may be the problem but there the same error occurs of having no profile with UUID. This is probably due to false documentation  that I did on the computers but I'm still not quite sure where it goes wrong.
#
# To see where it goes wrong I looked at the scripts that are launched in the startAllEpucks script and see if they work on their own. The first thing is the epuckXXX link that is called. All the epuck scripts are a link to the shell of startEpuck(epuckXXX -> startEpuck). While trying to start this script, there was once again an error with a shared library. This time it was the share library of liblog.so.4. There was not much time left to search on the internet for sources so I haven't tried that many sources to install the package.
